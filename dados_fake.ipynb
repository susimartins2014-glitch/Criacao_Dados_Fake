# %% [markdown]
# <a href="https://colab.research.google.com/github/susimartins2014-glitch/Criacao_Dados_Fake/blob/main/dados_fake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.6 MB/s eta 0:00:00
# ...

# %%
from faker import Faker
import pandas as pd

# %%
nome = []
empresa = []
cidade = []
pais = []
cargo = []
endereco = []
email = []
data_nasc = []

for a in range(0,100):

  nome.append(fake.name())
  empresa.append(fake.company())
  cidade.append(fake.city())
  pais.append(fake.country())
  cargo.append(fake.job())
  endereco.append(fake.street_address())
  email.append(fake.email())
  data_nasc.append(fake.date_of_birth())

print(data_nasc)
# Out:
# [datetime.date(1984, 9, 7), datetime.date(1914, 11, 20), datetime.date(1953, 8, 13), datetime.date(1995, 4, 26), datetime.date(1916, 2, 3), datetime.date(1918, 3, 1), datetime.date(1952, 8, 6), datetime.date(1973, 5, 10), datetime.date(2015, 4, 23), datetime.date(1995, 4, 23), datetime.date(1962, 3, 7), datetime.date(2000, 2, 17), datetime.date(1917, 2, 24), datetime.date(1955, 1, 22), datetime.date(1951, 4, 27), datetime.date(1998, 11, 24), datetime.date(1973, 7, 11), datetime.date(1949, 10, 13), datetime.date(1962, 1, 20), datetime.date(2004, 8, 25), datetime.date(1952, 2, 20), datetime.date(2006, 2, 17), datetime.date(1950, 4, 4), datetime.date(1914, 5, 14), datetime.date(1966, 9, 28), datetime.date(1979, 12, 29), datetime.date(2015, 11, 17), datetime.date(1997, 1, 17), datetime.date(1921, 10, 10), datetime.date(1914, 6, 27), datetime.date(2005, 7, 12), datetime.date(2024, 1, 15), datetime.date(2019, 4, 25), datetime.date(2001, 1, 19), datetime.date(2015, 9, 2), datetime.date(1921
# ...

# %%
df = pd.DataFrame(
    {
        'NOME': nome,
        'EMPRESA': empresa,
        'CIDADE': cidade,
        'PAIS': pais,
        'CARGO': cargo,
        'ENDERECO': endereco,
        'EMAIL': email,
        'DATA_NASCIMENTO': data_nasc

    }
)

print(df)
# Out:
#                       NOME                    EMPRESA               CIDADE  \
# 0           Stella da Cruz                     da Luz        Jesus de Rios
# 1    Pedro Miguel Carvalho                Casa Grande  Vasconcelos da Mata
# 2         Maria Luísa Lima                   Oliveira      Mendes do Galho
# 3   Luiz Felipe Montenegro                     Barros                Jesus
# 4   Davi Lucas Albuquerque         Cirino da Luz S.A.              Ribeiro
# ..                     ...                        ...                  ...
# 95             Ísis Vargas                 Sales - EI   Porto de Fernandes
# 96    João Felipe da Costa                  Leão - ME               Campos
# 97          Giovanna Souza     Jesus Casa Grande S.A.             da Rocha
# 98            Lara Ribeiro  Pereira da Conceição - EI      Duarte da Praia
# 99             André Cunha          da Conceição - EI                Pinto
#
#                      PAIS                          CARGO  \
# ...

# %%
df.to_csv('./DADOS_FAKE.CSV', index=False)
